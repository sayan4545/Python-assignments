# %% [markdown]
# ## Programming Assignment_1
# -------------

# %% [markdown]
# ### 1. Write a Python program to print "Hello Python"?

# %%
# python program to print "Hello Python"
print("Hello Python")
# Out:
# Hello Python

# %% [markdown]
# ### 2. Write a Python program to do arithmetical operations addition and division.?

# %%
# take input from user
a = int(input('enter an integer: '))
b = int(input('Enter an integer: '))

print("The addition of two integers a and b is ", a+b)
print("The division of two integers a and b is ", a/b)
# Out:
# enter an integer: 4
# Enter an integer: 2
# The addition of two integers a and b is  6
# The division of two integers a and b is  2.0

# %% [markdown]
# ### 3. Write a Python program to find the area of a triangle?

# %%
a = float(input('Enter first side: '))
b = float(input('Enter second side: '))
c = float(input('Enter third side: '))

# calculate the semi-perimeter
s = (a + b + c) / 2

# calculate the area
area = (s*(s-a)*(s-b)*(s-c)) ** 0.5
print('The area of the triangle is %0.2f' %area)
# Out:
# Enter first side: 4
# Enter second side: 9
# Enter third side: 10
# The area of the triangle is 17.98

# %% [markdown]
# ### 4. Write a Python program to swap two variables?

# %%
# Python program to swap two variables

#  taking inputs from the user
x = input('Enter value of x: ')
y = input('Enter value of y: ')

# create a temporary variable and swap the values
temp = x
x = y
y = temp

print('The value of x after swapping: {}'.format(x))
print('The value of y after swapping: {}'.format(y))
# Out:
# Enter value of x: 5
# Enter value of y: 4
# The value of x after swapping: 4
# The value of y after swapping: 5

# %% [markdown]
# ### 5. Write a Python program to generate a random number?

# %%
# Program to generate a random number between 0 and 9


import random

print(random.randint(0,9))
# Out:
# 5
